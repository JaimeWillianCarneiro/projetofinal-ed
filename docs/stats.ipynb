# %% [markdown]
# # Estatisticas

# %%
import pandas  as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.ticker import FuncFormatter
from matplotlib.colors import Normalize # Importar Normalize para mapear valores para 0-1

# %%
df = pd.read_csv('avl1000.csv')

# %% [markdown]
# ### Crescimento Estrutural

# %% [markdown]
# #### Altura da arvore

# %%
# Ativar tema mais limpo
sns.set_style("whitegrid")

# Dados
n_docs = df['Num_Docs']
altura = df['Altura']

# Criar a figura
plt.figure(figsize=(8, 5))
plt.plot(n_docs, altura, linestyle='-', color='#1f77b4', linewidth=2, markersize=6)

# Rótulos e título com melhor formatação
plt.xlabel('Número de Documentos', fontsize=12)
plt.ylabel('Altura da Árvore AVL', fontsize=12)
plt.title('Crescimento da Altura em uma Árvore AVL vs. Número de Documentos', fontsize=14, fontweight='bold')
# Remover as bordas superior e direita
sns.despine(top=True, right=True)
# Melhorar os ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Adicionar grade
# plt.grid(True, which='major', linestyle='--', alpha=0.7)
plt.grid(False)
# Ajustar layout
plt.tight_layout()

# Mostrar o gráfico
plt.show()

# %% [markdown]
# #### Total de Nós

# %%
# Estilo visual limpo
sns.set_style("whitegrid")

# Dados
n_docs = df['Num_Docs']
total_nos = df['Total_Nos']

# Criar a figura
plt.figure(figsize=(10, 6))
plt.plot(n_docs, total_nos, linestyle='-', color='#ff7f0e', linewidth=2)

# Rótulos e título
plt.xlabel('Número de Documentos', fontsize=12)
plt.ylabel('Total de Nós na Árvore AVL', fontsize=12)
plt.title('Crescimento do Total de Nós em uma Árvore AVL vs. Número de Documentos',
          fontsize=14, fontweight='bold')

# Estética
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
sns.despine(top=True, right=True)
plt.grid(False)

# Layout final
plt.tight_layout()

# Mostrar gráfico
plt.show()

# %% [markdown]
# #### Profundidade Média

# %%
# Estilo visual
sns.set_style("whitegrid")

# Dados
n_docs = df['Num_Docs']
profundidade_media = df['Profundidade_Media']

# Criar figura
plt.figure(figsize=(10, 6))
plt.plot(n_docs, profundidade_media,  linestyle='-', color='#9467bd', linewidth=2)

# Rótulos e título
plt.xlabel('Número de Documentos', fontsize=12)
plt.ylabel('Profundidade Média dos Nós', fontsize=12)
plt.title('Profundidade Média em uma Árvore AVL vs. Número de Documentos',
          fontsize=14, fontweight='bold')

# Estética
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
sns.despine(top=True, right=True)
plt.grid(False)

# Layout
plt.tight_layout()

# Mostrar gráfico
plt.show()

# %%
# Estilo visual
sns.set_style("whitegrid")

# Dados
n_docs = df['Num_Docs']
profundidade_media = df['Profundidade_Media']

# Ajuste logarítmico (modelo: y = a * log(x) + b)
log_n_docs = np.log(n_docs)
coef = np.polyfit(log_n_docs, profundidade_media, deg=1)
ajuste = coef[0] * log_n_docs + coef[1]

# Criar figura
plt.figure(figsize=(10, 6))

# Pontos reais
plt.scatter(n_docs, profundidade_media, color='#1f77b4',s=20, alpha= 0.7,  label='Dados observados')

# Linha conectando os pontos
plt.plot(n_docs, profundidade_media, linestyle='-', color='#9467bd', alpha=0.6)

# Linha do ajuste logarítmico
plt.plot(n_docs, ajuste, linestyle='--', color='orange', linewidth=2, label='Ajuste logarítmico')

# Eixo x em escala logarítmica para realçar a relação
plt.xscale('log')

# Rótulos e título
plt.xlabel('Número de Documentos (escala logarítmica)', fontsize=12)
plt.ylabel('Profundidade Média dos Nós', fontsize=12)
plt.title('Profundidade Média em Árvore AVL vs. Número de Documentos', fontsize=14, fontweight='bold')

# Legenda
plt.legend()

# Estética dos ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
sns.despine(top=True, right=True)

# Layout ajustado
plt.tight_layout()
plt.grid(False)
# Mostrar gráfico
plt.show()

# %% [markdown]
# O gráfico apresentado mostra a relação entre o "Número de Documentos" (em escala logarítmica) e a "Profundidade Média dos Nós" naárvore AVL.
#
# **Análise:**
#
# 1.  **Dados Observados (Pontos Azuis):** Os pontos azuis representam os dados coletados, mostrando a profundidade média dos nós para diferentes números de documentos. Percebe-se que, à medida que o número de documentos aumenta, a profundidade média dos nós também aumenta.
#
# 2.  **Linha Conectando os Pontos (Linha Roxa Clara):** Essa linha mostra a trajetória dos dados observados. No início, para um número muito pequeno de documentos, a profundidade média dos nós tem um comportamento mais irregular e com saltos maiores. No entanto, à medida que o número de documentos cresce, a profundidade média dos nós se torna mais suave e previsível.
#
# 3.  **Ajuste Logarítmico (Linha Laranja Tracejada):** Uma linha de ajuste logarítmico foi sobreposta aos dados. Essa linha representa um modelo do tipo $y = a \cdot \log(x) + b$, onde $y$ é a profundidade média e $x$ é o número de documentos.
#
# 4.  **Qualidade do Ajuste Logarítmico:**
#     * Para um número maior de documentos (a partir de aproximadamente $10^1$ ou 10 documentos), o ajuste logarítmico parece se encaixar muito bem aos dados observados. A linha laranja tracejada acompanha de perto os pontos azuis, indicando que a profundidade média dos nós em uma árvore AVL cresce de forma logarítmica com o número de documentos.
#     * Para um número muito pequeno de documentos (abaixo de 10), o ajuste logarítmico não é tão preciso. Há uma diferença notável entre os dados observados e a linha de ajuste, especialmente na porção inicial do gráfico. Isso é esperado, pois o comportamento de uma estrutura de dados para um volume muito pequeno de elementos pode não seguir perfeitamente a complexidade assintótica que se aplica a volumes maiores.
#
# **Conclusão:**
#
# O gráfico ilustra um conceito fundamental sobre árvores AVL: sua altura (e, consequentemente, a profundidade média dos nós) cresce de forma logarítmica com o número de elementos. Isso é uma das principais vantagens das árvores AVL, pois garante que as operações (inserção, busca, remoção) tenham uma complexidade de tempo logarítmica, mesmo no pior caso, devido ao seu auto-balanceamento.
#
# O ajuste logarítmico confirma essa característica teórica para um volume significativo de documentos, demonstrando empiricamente o desempenho eficiente das árvores AVL em termos de profundidade. As pequenas discrepâncias para poucos documentos são normalmente irrelevantes em cenários de uso prático, onde as árvores AVL são aplicadas para gerenciar grandes volumes de dados.

# %% [markdown]
# #### Profundidade Mínima

# %%
# Estilo visual
sns.set_style("whitegrid")

# Dados
n_docs = df['Num_Docs']
profundidade_min = df['Profundidade_Minima']

# Criar gráfico
plt.figure(figsize=(10, 6))
plt.plot(n_docs, profundidade_min, linestyle='-', color='#d62728', linewidth=2)

# Rótulos e título
plt.xlabel('Número de Documentos', fontsize=12)
plt.ylabel('Profundidade Mínima dos Nós', fontsize=12)
plt.title('Profundidade Mínima em uma Árvore AVL vs. Número de Documentos',
          fontsize=14, fontweight='bold')

# Estética
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
sns.despine(top=True, right=True)
plt.grid(False)

# Ajuste final
plt.tight_layout()

# Mostrar gráfico
plt.show()

# %%
# Estilo visual limpo
sns.set_style("whitegrid")

# Dados
n_docs = df['Num_Docs']
altura = df['Altura']
prof_min = df['Profundidade_Minima']
prof_media = df['Profundidade_Media']

# Criar figura
plt.figure(figsize=(10, 6))

# Plotagens com cores distintas
plt.plot(n_docs, prof_min, linestyle='-', color='#d62728', label='Profundidade Mínima', linewidth=2, markersize=5)
plt.plot(n_docs, prof_media, linestyle='-', color='#ff7f0e', label='Profundidade Média', linewidth=2, markersize=5)
plt.plot(n_docs, altura,  linestyle='-', color='#1f77b4', label='Altura da Árvore', linewidth=2, markersize=5)

# Rótulos e título
plt.xlabel('Número de Documentos', fontsize=12)
plt.ylabel('Valor', fontsize=12)
plt.title('Altura, Profundidade Média e Mínima em uma Árvore AVL', fontsize=14, fontweight='bold')

# Legenda
plt.legend(fontsize=10)

# Estética
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
sns.despine(top=True, right=True)
plt.grid(False)
plt.tight_layout()

# Exibir
plt.show()

# %% [markdown]
# Altura: deve crescer de forma logarítmica, mas sempre maior que as demais curvas.
#
# Profundidade Média: deve crescer mais suavemente, acompanhando parcialmente a altura.
#
# Profundidade Mínima: geralmente cresce devagar — se for constante, indica subárvores rasas.
#
# Como houve saltos ou quebras de padrão, isso pode indicar inserções que impactaram partes da árvore mais rasas.

# %%
# Configura estilo visual
sns.set_style("whitegrid")

# Plot
plt.figure(figsize=(10,6))
plt.plot(df['Num_Docs'], df['Max_Desbalanceamento'], marker='o', linestyle='-', color='tab:blue')

# Títulos e legendas
plt.title('Número de Documentos vs. Máximo Desbalanceamento')
plt.xlabel('Número de Documentos (Num_Docs)')
plt.ylabel('Máximo Desbalanceamento (Max_Desbalanceamento)')

plt.tight_layout()
plt.show()

# %% [markdown]
# Na árvore AVL, o máximo desbalanceamento (diferença de altura entre subárvores) não passa de 1, porque essa é justamente a propriedade da AVL para garantir o balanceamento.

# %% [markdown]
# #### Densidade

# %%
# Estilo limpo
sns.set_style("whitegrid")

# Dados
n_docs = df['Num_Docs']
densidade = df['Densidade_Arvore']

# Figura
plt.figure(figsize=(10, 6))
plt.plot(n_docs, densidade, linestyle='-', color='#2ca02c', linewidth=2, markersize=4)

# Rótulos e título
plt.xlabel('Número de Documentos', fontsize=12)
plt.ylabel('Densidade da Árvore AVL', fontsize=12)
plt.title('Evolução da Densidade Estrutural da Árvore AVL', fontsize=14, fontweight='bold')

# Limites e detalhes
plt.ylim(0, 1.05)  # densidade no máximo 1
plt.axhline(1.0, color='gray', linestyle='--', linewidth=1, alpha=0.5)  # linha de referência
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
sns.despine(top=True, right=True)
# plt.grid(True, linestyle='--', alpha=0.6)
plt.grid(False)
plt.tight_layout()

# Exibir
plt.show()

# %% [markdown]
# Razaão Maior/Menor Galho

# %%
# Estilo visual
sns.set_style("whitegrid")

# Calcular a razão Maior_Galho / Menor_Galho
# Adiciona um pequeno valor ao denominador para evitar divisão por zero, caso ocorra
df['Razao_Galhos'] = df['Maior_Galho'] / (df['Menor_Galho'] + 1e-9)

# Criar figura
plt.figure(figsize=(10, 6))

# Plotar a razão vs. Número de Documentos
plt.plot(df['Num_Docs'], df['Razao_Galhos'], marker='o', linestyle='-', color='#2ca02c', label='Razão Maior/Menor Galho')

# Eixo x em escala logarítmica
plt.xscale('log')

# Rótulos e título
plt.xlabel('Número de Documentos (escala logarítmica)', fontsize=12)
plt.ylabel('Razão Maior/Menor Galho', fontsize=12)
plt.title('Razão Entre o Maior e o Menor Galho vs. Número de Documentos', fontsize=14, fontweight='bold')

# Legenda
plt.legend()

# Estética dos ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
sns.despine(top=True, right=True)

# Layout ajustado
plt.tight_layout()

# Salvar o gráfico
plt.savefig('razao_galhos_vs_num_docs.png')

# %% [markdown]
# ## Desempenho Temporal

# %%
# Ativar tema mais limpo
sns.set_style("whitegrid")

# Dados
n_docs = df['Num_Docs']
n_comparacoes_totais = df['Total_Comparacoes_Indexacao']

# Criar a figura
plt.figure(figsize=(8, 5))
plt.plot(n_docs, n_comparacoes_totais, linestyle='-', color='#1f77b4', linewidth=3, markersize=6)

# Rótulos e título com melhor formatação
plt.xlabel('Número de Documentos', fontsize=12)
plt.ylabel('Numero de comparações', fontsize=12)
plt.title('Numero de Comparações de Inserção em uma Árvore AVL vs. Número de Documentos', fontsize=14, fontweight='bold')
# Remover as bordas superior e direita
sns.despine(top=True, right=True)
# Melhorar os ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Adicionar grade
# plt.grid(True, which='major', linestyle='--', alpha=0.7)
plt.grid(False)
# Ajustar layout
plt.tight_layout()

# Mostrar o gráfico
plt.show()

# %%
# --- Gráfico 1: Num_Docs vs. Tempo_Total_Indexacao ---
plt.figure(figsize=(10, 6))
plt.plot(df['Num_Docs'], df['Tempo_Total_Indexacao'], linestyle='-', color='#d62728', label='Tempo Total de Indexação')
plt.xscale('log') # Eixo X em escala logarítmica
plt.xlabel('Número de Documentos (escala logarítmica)', fontsize=12)
plt.ylabel('Tempo Total de Indexação (ms)', fontsize=12)
plt.title('Tempo Total de Indexação vs. Número de Documentos', fontsize=14, fontweight='bold')
plt.legend()
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
sns.despine(top=True, right=True) # Remover bordas superiores e direitas
plt.tight_layout() # Ajustar layout para evitar sobreposição
plt.grid(False)
plt.show() #

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['Num_Docs'], df['Tempo_Medio_Insercao'],  linestyle='-', color='#9467bd', label='Tempo Médio de Inserção')
plt.xscale('log') # Eixo X em escala logarítmica
plt.xlabel('Número de Documentos (escala logarítmica)', fontsize=12)
plt.ylabel('Tempo Médio de Inserção (ms)', fontsize=12)
plt.title('Tempo Médio de Inserção vs. Número de Documentos', fontsize=14, fontweight='bold')
plt.legend()
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
sns.despine(top=True, right=True) # Remover bordas superiores e direitas
plt.tight_layout() # Ajustar layout para evitar sobreposição
plt.grid(False)
plt.show() # Mostrar o gráfico (ou plt.savefig('nome_do_arquivo.png')

# %%
# Estilo visual
sns.set_style("whitegrid")

plt.figure(figsize=(10, 6))
sns.scatterplot(x='Altura', y='Total_Comparacoes_Indexacao', data=df, s=80, color='#1f77b4', label='Dados Observados') # Adicionada a label
plt.xlabel('Altura da Árvore', fontsize=12)
plt.ylabel('Total de Comparações na Indexação', fontsize=12)
plt.title('Altura da Árvore vs. Total de Comparações na Indexação', fontsize=14, fontweight='bold')
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
# plt.legend() # Chama a legenda
sns.despine(top=True, right=True)
plt.tight_layout()
plt.grid(False)
plt.show()

# %%
# --- Gráfico 2: Altura vs. Tempo_Medio_Insercao (Dispersão + Linha de Tendência) ---
plt.figure(figsize=(10, 6))
sns.regplot(x='Altura', y='Tempo_Medio_Insercao', data=df, scatter_kws={'s':80, 'color': '#ff7f0e'}, line_kws={'color': '#1f77b4'})
plt.xlabel('Altura da Árvore', fontsize=12)
plt.ylabel('Tempo Médio de Inserção (segundos)', fontsize=12)
plt.title('Altura da Árvore vs. Tempo Médio de Inserção', fontsize=14, fontweight='bold')
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
sns.despine(top=True, right=True)
plt.tight_layout()
plt.grid(False)
plt.show()

# %%
# --- Gráfico 3: Total_Nos vs. Tempo_Total_Indexacao (Dispersão) ---
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Total_Nos', y='Tempo_Total_Indexacao', data=df, s=80, color='#2ca02c', label='Dados Observados') # Adicionada a label
plt.xscale('log') # Eixo X em escala logarítmica, pois Total_Nos pode variar muito
plt.xlabel('Total de Nós na Árvore (escala logarítmica)', fontsize=12)
plt.ylabel('Tempo Total de Indexação (ms)', fontsize=12)
plt.title('Total de Nós na Árvore vs. Tempo Total de Indexação', fontsize=14, fontweight='bold')
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
# plt.legend() # Chama a legenda
plt.grid(False)
sns.despine(top=True, right=True)
plt.tight_layout()
plt.show()

# %%
# Calcular a razão Maior_Galho / Menor_Galho para o heatmap
df['Razao_Galhos'] = df['Maior_Galho'] / (df['Menor_Galho'] + 1e-9)

# Estilo visual
sns.set_style("whitegrid")

# --- Gráfico: Mapa de calor de correlação (heatmap) com ajuste de cor de texto ---
plt.figure(figsize=(14, 12)) # Tamanho da figura

# Selecionar apenas as colunas numéricas para o heatmap
numeric_cols = df.select_dtypes(include=np.number).columns
correlation_matrix = df[numeric_cols].corr()

# Criar o heatmap SEM anotações automáticas do seaborn
ax = sns.heatmap(
    correlation_matrix,
    annot=False,      # Desativa anotações automáticas do seaborn
    cmap='cividis',   # Mapa de cores
    fmt=".2f",        # Formato de duas casas decimais (será usado na anotação manual)
    linewidths=.5,    # Largura das linhas entre as células
    cbar_kws={'shrink': 0.75} # Pode ajudar a ajustar a barra de cor
)

plt.title('Mapa de Calor da Matriz de Correlação', fontsize=16, fontweight='bold')
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(rotation=0, fontsize=10)

# Lógica para adicionar anotações com cor de texto adaptativa
cmap = plt.cm.get_cmap('cividis') # Pega o colormap para usar na normalização
norm = Normalize(vmin=correlation_matrix.values.min(), vmax=correlation_matrix.values.max()) # Normaliza os valores da matriz para o range do colormap

for i in range(correlation_matrix.shape[0]):
    for j in range(correlation_matrix.shape[1]):
        valor = correlation_matrix.iloc[i, j]
        rgba = cmap(norm(valor))  # Valor RGBA da célula
        
        # Calcula luminância percebida para escolher branco/preto (fórmula perceptual)
        # Os valores RGBA já estão normalizados para 0-1, então não precisa dividir por 255
        luminancia = 0.299 * rgba[0] + 0.587 * rgba[1] + 0.114 * rgba[2]
        
        cor_texto = "black" if luminancia > 0.5 else "white"
        
        ax.text(j + 0.5, i + 0.5, f"{valor:.2f}", ha='center', va='center', color=cor_texto, fontsize=8) # Usar fontsize=8 ou 7 se necessário

plt.tight_layout() # Ajustar o layout para que tudo caiba
plt.show()
# Out:
# C:\Users\jaime\AppData\Local\Temp\ipykernel_13244\3295743564.py:29: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap('cividis') # Pega o colormap para usar na normalização

# %%
correlation_matrix
# Out:
#                              Num_Docs    Altura  Total_Nos  \
# Num_Docs                     1.000000  0.808067   0.944224
# Altura                       0.808067  1.000000   0.887598
# Total_Nos                    0.944224  0.887598   1.000000
# Profundidade_Media           0.771088  0.942417   0.914658
# Profundidade_Minima          0.628998  0.879536   0.812201
# Max_Desbalanceamento              NaN       NaN        NaN
# Tempo_Total_Indexacao        0.983484  0.731657   0.872553
# Tempo_Medio_Insercao         0.992799  0.754833   0.904900
# Densidade_Arvore            -0.517689 -0.747723  -0.464377
# Maior_Galho                  0.808067  1.000000   0.887598
# Menor_Galho                  0.628998  0.879536   0.812201
# Total_Comparacoes_Indexacao  0.999837  0.802636   0.943408
# Razao_Galhos                 0.322225  0.201851   0.117528
#
#                              Profundidade_Media  Profundidade_Minima  \
# Num_Docs                               0.771088             0.628998
# Altura                                 0.942417             0.879536
# Total_Nos                              0.914658             0.812201
# Profundidade_Media                     1.000000             0.939848
# Profundidade_Minima                    0.939848             1.000000
# Max_Desbalanceamento                        NaN                  NaN
# Tempo_Total_Indexacao                  0.668803             0.509407
# Tempo_Medio_Insercao                   0.708991             0.555918
# Densidade_Arvore                      -0.490770            -0.466450
# Maior_Galho                            0.942417             0.879536
# Menor_Galho                            0.939848             1.000000
# Total_Comparacoes_Indexacao            0.767783             0.625106
# Razao_Galhos                          -0.030653            -0.283595
#
#                              Max_Desbalanceamento  Tempo_Total_Indexacao  \
# Num_Docs                                      NaN               0.983484
# Altura                                        NaN               0.731657
# Total_Nos                                     NaN               0.872553
# Profundidade_Media                            NaN               0.668803
# Profundidade_Minima                           NaN               0.509407
# Max_Desbalanceamento                          NaN                    NaN
# Tempo_Total_Indexacao                         NaN               1.000000
# Tempo_Medio_Insercao                          NaN               0.996601
# Densidade_Arvore                              NaN              -0.513129
# Maior_Galho                                   NaN               0.731657
# Menor_Galho                                   NaN               0.509407
# Total_Comparacoes_Indexacao                   NaN               0.983925
# Razao_Galhos                                  NaN               0.407941
#
#                              Tempo_Medio_Insercao  Densidade_Arvore  \
# Num_Docs                                 0.992799         -0.517689
# Altura                                   0.754833         -0.747723
# Total_Nos                                0.904900         -0.464377
# Profundidade_Media                       0.708991         -0.490770
# Profundidade_Minima                      0.555918         -0.466450
# Max_Desbalanceamento                          NaN               NaN
# Tempo_Total_Indexacao                    0.996601         -0.513129
# Tempo_Medio_Insercao                     1.000000         -0.496368
# Densidade_Arvore                        -0.496368          1.000000
# Maior_Galho                              0.754833         -0.747723
# Menor_Galho                              0.555918         -0.466450
# Total_Comparacoes_Indexacao              0.993419         -0.509889
# Razao_Galhos                             0.362475         -0.542818
#
#                              Maior_Galho  Menor_Galho  \
# Num_Docs                        0.808067     0.628998
# Altura                          1.000000     0.879536
# Total_Nos                       0.887598     0.812201
# Profundidade_Media              0.942417     0.939848
# Profundidade_Minima             0.879536     1.000000
# Max_Desbalanceamento                 NaN          NaN
# Tempo_Total_Indexacao           0.731657     0.509407
# Tempo_Medio_Insercao            0.754833     0.555918
# Densidade_Arvore               -0.747723    -0.466450
# Maior_Galho                     1.000000     0.879536
# Menor_Galho                     0.879536     1.000000
# Total_Comparacoes_Indexacao     0.802636     0.625106
# Razao_Galhos                    0.201851    -0.283595
#
#                              Total_Comparacoes_Indexacao  Razao_Galhos
# Num_Docs                                        0.999837      0.322225
# Altura                                          0.802636      0.201851
# Total_Nos                                       0.943408      0.117528
# Profundidade_Media                              0.767783     -0.030653
# Profundidade_Minima                             0.625106     -0.283595
# Max_Desbalanceamento                                 NaN           NaN
# Tempo_Total_Indexacao                           0.983925      0.407941
# Tempo_Medio_Insercao                            0.993419      0.362475
# Densidade_Arvore                               -0.509889     -0.542818
# Maior_Galho                                     0.802636      0.201851
# Menor_Galho                                     0.625106     -0.283595
# Total_Comparacoes_Indexacao                     1.000000      0.319613
# Razao_Galhos                                    0.319613      1.000000
